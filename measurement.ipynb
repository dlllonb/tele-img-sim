# %% [markdown]
# # Measurement / Analysis Pipeline
#
# This notebook will orchestrate the measurement stage: star finding, plate solving, diffraction orientation, and metric evaluation.
# It imports the `measure` package defined alongside `sim` and exercises the full analysis chain.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from measure.pipeline import run_measurement_pipeline

# %%
result = run_measurement_pipeline(
    #"data/fuji6_asi178_100_15s.fit",
    "data/m81.fits",
    output_dir="out",
    run_name="testnew",
    save_outputs=True,
    keep_intermediates=True,
    show=True,
)
# Out:
# Solving..........
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
# loaded FITS
# created run directory out\testnew
# star branch: background subtracted (Gaussian sigma=50 px)
# stripe branch: background subtracted (Gaussian sigma=50 px), smoothed (sigma=2.5 px)
# wrote branch FITS files
# diffraction angle stage completed
# ensemble: 494/2054 segments accepted, angle=82.34° ± 51.46°, quality=0.021, INVALID
# stripe mask applied: 647028 px blanked
# platesolve stage completed
# submitting 300 sources to nova.astrometry.net
# solved: RA=150.36715° Dec=69.18965° rot=88.122°
# metrics computed
# wrote summary files

# %%
result = run_measurement_pipeline(
    "data/fuji6_asi178_100_15s.fit",
    #"data/m81.fits",
    output_dir="out",
    run_name="testnew",
    save_outputs=True,
    keep_intermediates=True,
    show=True,
)
# Out:
# Solving..........
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
# loaded FITS
# created run directory out\testnew
# star branch: background subtracted (Gaussian sigma=50 px)
# stripe branch: background subtracted (Gaussian sigma=50 px), smoothed (sigma=2.5 px)
# wrote branch FITS files
# diffraction angle stage completed
# ensemble: 191/745 segments accepted, angle=22.67° ± 3.73°, quality=0.992, valid
# stripe mask applied: 235412 px blanked
# platesolve stage completed
# submitting 103 sources to nova.astrometry.net
# solved: RA=120.62732° Dec=29.80811° rot=-178.145°
# metrics computed
# wrote summary files
